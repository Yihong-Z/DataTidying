# %% [markdown]
# <a href="https://colab.research.google.com/github/Yihong-Z/DataTidying/blob/main/Matrix0506.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Read in data

# %%
import pandas as pd
import numpy as np

# %%
carbon=pd.read_csv("/content/Biochar carbon stock 100 year_1km_pature_lower_yr2.csv")
df=pd.read_csv("/content/Dead tree_pasture_1km_lower.csv")
row=pd.read_csv("/content/Row1.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
row.head()
# Out:
#    Carbon stock
# 0    516.077809
# 1    213.498891
# 2    212.999796
# 3    212.615905
# 4    212.253905

# %%
row_matrix=np.array(row.transpose())

# %%
df.head()
# Out:
#    pointid     SI  1         2         3         4         5         6  \
# 0      1.0  100.0  0  0.000808  0.004633  0.022418  0.066473  0.152868
# 1      6.0  100.0  0  0.000808  0.004633  0.022418  0.066473  0.152868
# 2     12.0   79.0  0  0.000709  0.006546  0.009268  0.040315  0.110476
# 3     17.0   98.0  0  0.004866  0.029183  0.140289  0.414871  0.952972
# 4     18.0   77.0  0  0.000163  0.001580  0.002226  0.009612  0.026260
#
#           7         8  ...         91         92         93         94  \
# 0  0.299574  0.368845  ...   2.273333   2.402403   2.518093   3.295817
# 1  0.299574  0.368845  ...   2.273333   2.402403   2.518093   3.295817
# 2  0.240183  0.294589  ...   2.217918   2.361950   2.495736   2.618450
# 3  1.866733  2.297738  ...  14.214576  15.031839  15.766964  16.416736
# 4  0.057013  0.069874  ...   0.527322   0.561928   0.594173   0.623852
#
#           95         96         97         98         99        100
# ...

# %%
#DROP MULTIPLE COLUMNS: dataframe.drop(columns=['column_name_1', 'column_name_2'])
#df.iloc[:,0:3]
df_base=df.drop(columns=["pointid","SI","1"])

# %%
df_base=df_base.drop([11710])

# %%
df_base.shape
# Out:
# (11710, 99)

# %%
df_base
# Out:
#               2         3         4         5         6         7         8  \
# 0      0.000808  0.004633  0.022418  0.066473  0.152868  0.299574  0.368845
# 1      0.000808  0.004633  0.022418  0.066473  0.152868  0.299574  0.368845
# 2      0.000709  0.006546  0.009268  0.040315  0.110476  0.240183  0.294589
# 3      0.004866  0.029183  0.140289  0.414871  0.952972  1.866733  2.297738
# 4      0.000163  0.001580  0.002226  0.009612  0.026260  0.057013  0.069874
# ...         ...       ...       ...       ...       ...       ...       ...
# 11705  0.000275  0.001973  0.009221  0.026945  0.061565  0.078432  0.147906
# 11706  0.000825  0.005920  0.027662  0.080836  0.184694  0.235296  0.443718
# 11707  0.001593  0.014255  0.028222  0.115917  0.149314  0.388084  0.472458
# 11708  0.000825  0.005920  0.027662  0.080836  0.184694  0.235296  0.443718
# 11709  0.000677  0.005445  0.024953  0.034694  0.095855  0.209142  0.257006
#
# ...

# %%
df_matrix=np.array(df_base)

# %%
df_matrix[:,0]
# Out:
# array([0.00080791, 0.00080791, 0.00070942, ..., 0.00159319, 0.00082476,
#        0.00067741])

# %%
df_matrix_1=np.matrix(df_base.iloc[:,0]).transpose()

# %%
df_matrix_1
# Out:
# matrix([[0.00080791],
#         [0.00080791],
#         [0.00070942],
#         ...,
#         [0.00159319],
#         [0.00082476],
#         [0.00067741]])

# %%
row_matrix
# Out:
# array([[516.0778087, 213.4988909, 212.9997964, 212.615905 , 212.2539052,
#         211.8964608, 211.5403502, 211.1849739, 210.83022  , 210.4760667,
#         210.1225091, 209.7695456, 209.4171751, 209.0653965, 208.7142088,
#         208.363611 , 208.0136021, 207.6641812, 207.3153473, 206.9670993,
#         206.6194363, 206.2723573, 205.9258614, 205.5799474, 205.2346146,
#         204.8898618, 204.5456882, 204.2020927, 203.8590743, 203.5166322,
#         203.1747653, 202.8334726, 202.4927533, 202.1526063, 201.8130307,
#         201.4740255, 201.1355898, 200.7977225, 200.4604229, 200.1236898,
#         199.7875223, 199.4519196, 199.1168806, 198.7824044, 198.44849  ,
#         198.1151366, 197.7823431, 197.4501086, 197.1184323, 196.7873131,
#         196.4567501, 196.1267423, 195.797289 , 195.468389 , 195.1400415,
#         194.8122456, 194.4850003, 194.1583047, 193.8321579, 193.506559 ,
#         193.181507 , 192.857001 , 192.5330401, 192.2096235, 191.8867501,
# ...

# %%
#df_base.iloc[:,0]
#row_matrix.shape
#df_matrix_1[:,0].shape
df1=np.dot(df_matrix_1,row_matrix)
#row_matrix*df_matrix_1

# %%
pd.DataFrame(df1)
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.416946  0.172489  0.172085  0.171775  0.171483  0.171194  0.170906
# 1      0.416946  0.172489  0.172085  0.171775  0.171483  0.171194  0.170906
# 2      0.366114  0.151460  0.151105  0.150833  0.150576  0.150323  0.150070
# 3      2.511354  1.038935  1.036506  1.034638  1.032877  1.031137  1.029404
# 4      0.084315  0.034881  0.034799  0.034737  0.034677  0.034619  0.034561
# ...         ...       ...       ...       ...       ...       ...       ...
# 11705  0.141881  0.058695  0.058558  0.058453  0.058353  0.058255  0.058157
# 11706  0.425642  0.176086  0.175675  0.175358  0.175059  0.174765  0.174471
# 11707  0.822208  0.340144  0.339349  0.338737  0.338160  0.337591  0.337023
# 11708  0.425642  0.176086  0.175675  0.175358  0.175059  0.174765  0.174471
# 11709  0.349595  0.144626  0.144288  0.144028  0.143782  0.143540  0.143299
#
# ...

# %%
b=[]

# %%
#循环生成数据框的名字/生成一个有99个位置的list
for i in range(0,99): #生成0-98的99个数字
  b.append("df"+str(i))
  print(b)

# %% [markdown]
# #Produce 99 dataframes

# %%
#Basic formula
#b[0]=np.dot(df_matrix_1,row_matrix)
#df_matrix_1=np.matrix(df_base.iloc[:,0]).transpose()

# %%
for i in range(0,99):
  b[i]=np.dot(np.matrix(df_base.iloc[:,i]).transpose(),row_matrix)

# %%
pd.DataFrame(b[0])
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.416946  0.172489  0.172085  0.171775  0.171483  0.171194  0.170906
# 1      0.416946  0.172489  0.172085  0.171775  0.171483  0.171194  0.170906
# 2      0.366114  0.151460  0.151105  0.150833  0.150576  0.150323  0.150070
# 3      2.511354  1.038935  1.036506  1.034638  1.032877  1.031137  1.029404
# 4      0.084315  0.034881  0.034799  0.034737  0.034677  0.034619  0.034561
# ...         ...       ...       ...       ...       ...       ...       ...
# 11705  0.141881  0.058695  0.058558  0.058453  0.058353  0.058255  0.058157
# 11706  0.425642  0.176086  0.175675  0.175358  0.175059  0.174765  0.174471
# 11707  0.822208  0.340144  0.339349  0.338737  0.338160  0.337591  0.337023
# 11708  0.425642  0.176086  0.175675  0.175358  0.175059  0.174765  0.174471
# 11709  0.349595  0.144626  0.144288  0.144028  0.143782  0.143540  0.143299
#
# ...

# %%
#Choose one column of the datafram
b[0][:,0]
# Out:
# matrix([[0.41694597],
#         [0.41694597],
#         [0.36611385],
#         ...,
#         [0.82220846],
#         [0.4256424 ],
#         [0.34959472]])

# %% [markdown]
# #Sum

# %%
#Basic formula
b[0][:,1]+b[1][:,0]

# %%
b[0][:,0]
# Out:
# matrix([[0.41694597],
#         [0.41694597],
#         [0.36611385],
#         ...,
#         [0.82220846],
#         [0.4256424 ],
#         [0.34959472]])

# %%
df_none=pd.DataFrame()
df_none.loc[:,0]=pd.DataFrame(b[0][:,0])
df_none

# %%
#Test
df_none.loc[:,0]=pd.DataFrame(b[0][:,1])
df_none.loc[:,1]=pd.DataFrame(b[1][:,0])
df_none
# Out:
#               0          1
# 0      0.172489   2.390960
# 1      0.172489   2.390960
# 2      0.151460   3.378174
# 3      1.038935  15.060931
# 4      0.034881   0.815215
# ...         ...        ...
# 11705  0.058695   1.018317
# 11706  0.176086   3.054951
# 11707  0.340144   7.356527
# 11708  0.176086   3.054951
# 11709  0.144626   2.810005
#
# [11710 rows x 2 columns]

# %%
pd.DataFrame(b[0])
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.416946  0.172489  0.172085  0.171775  0.171483  0.171194  0.170906
# 1      0.416946  0.172489  0.172085  0.171775  0.171483  0.171194  0.170906
# 2      0.366114  0.151460  0.151105  0.150833  0.150576  0.150323  0.150070
# 3      2.511354  1.038935  1.036506  1.034638  1.032877  1.031137  1.029404
# 4      0.084315  0.034881  0.034799  0.034737  0.034677  0.034619  0.034561
# ...         ...       ...       ...       ...       ...       ...       ...
# 11705  0.141881  0.058695  0.058558  0.058453  0.058353  0.058255  0.058157
# 11706  0.425642  0.176086  0.175675  0.175358  0.175059  0.174765  0.174471
# 11707  0.822208  0.340144  0.339349  0.338737  0.338160  0.337591  0.337023
# 11708  0.425642  0.176086  0.175675  0.175358  0.175059  0.174765  0.174471
# 11709  0.349595  0.144626  0.144288  0.144028  0.143782  0.143540  0.143299
#
# ...

# %%
df_none.sum(axis=1)
# Out:
# 0         2.563449
# 1         2.563449
# 2         3.529633
# 3        16.099866
# 4         0.850095
#            ...
# 11705     1.077012
# 11706     3.231038
# 11707     7.696671
# 11708     3.231038
# 11709     2.954631
# Length: 11710, dtype: float64

# %%
b[0][:,99]
# Out:
# matrix([[0.14616879],
#         [0.14616879],
#         [0.12834857],
#         ...,
#         [0.28824171],
#         [0.1492175 ],
#         [0.12255746]])

# %%
summ=[]
for i in range(0,99):
  summ.append("col"+str(i))
  print(summ)

# %%
for j in range(0,99): #0到98,99个数
    df_none=pd.DataFrame()
    for i in range(0,j+1): #0,...,98
        df_none.loc[:,i]=pd.DataFrame(b[i][:,j-i])
        #print(df_none)
    summ[i]=df_none.sum(axis=1) #axis=0行，axis=1列相加
    print(df_none)

# %%
summ
# Out:
# [0        0.416946
#  1        0.416946
#  2        0.366114
#  3        2.511354
#  4        0.084315
#             ...
#  11705    0.141881
#  11706    0.425642
#  11707    0.822208
#  11708    0.425642
#  11709    0.349595
#  Length: 11710, dtype: float64, 0         2.563449
#  1         2.563449
#  2         3.529633
#  3        16.099866
#  4         0.850095
#             ...
#  11705     1.077012
#  11706     3.231038
#  11707     7.696671
#  11708     3.231038
#  11709     2.954631
#  Length: 11710, dtype: float64, 0        12.730479
#  1        12.730479
#  2         6.331550
#  3        79.667055
#  4         1.520708
#             ...
#  11705     5.238498
#  11706    15.715493
#  11707    17.947672
#  11708    15.715493
#  11709    14.184703
#  Length: 11710, dtype: float64, 0         40.249901
#  1         40.249901
#  2         24.329293
#  3        251.308173
#  4          5.806775
#              ...
#  11705     16.353338
#  11706     49.060013
#  11707     69.222390
# ...

# %%
result=pd.DataFrame(summ).transpose()

# %%
result
# Out:
#              0          1          2           3           4            5   \
# 0      0.416946   2.563449  12.730479   40.249901   99.015010   207.320059
# 1      0.416946   2.563449  12.730479   40.249901   99.015010   207.320059
# 2      0.366114   3.529633   6.331550   24.329293   69.137568   159.636944
# 3      2.511354  16.099866  79.667055  251.308173  617.501625  1292.258630
# 4      0.084315   0.850095   1.520708    5.806775   16.448678    37.919793
# ...         ...        ...        ...         ...         ...          ...
# 11705  0.141881   1.077012   5.238498   16.353338   39.966899    61.797936
# 11706  0.425642   3.231038  15.715493   49.060013  119.900698   185.393808
# 11707  0.822208   7.696671  17.947672   69.222390  111.186200   266.213892
# 11708  0.425642   3.231038  15.715493   49.060013  119.900698   185.393808
# 11709  0.349595   2.954631  14.184703   24.535991   63.492007   142.392653
#
# ...

# %%
result.to_csv("/content/result.csv")
